# %%
import pandas as pd
import seaborn as sns
import numpy
import re

# %%
Data_Test=pd.read_excel(r"C:\Users\Prashant\Desktop\dataset\Participants\Data_Train.XLSX")

# %%
Data_Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11094 entries, 0 to 11093
# Data columns (total 9 columns):
# Restaurant       11094 non-null object
# Location         11094 non-null object
# Cuisines         11094 non-null object
# Average_Cost     11094 non-null object
# Minimum_Order    11094 non-null object
# Rating           11094 non-null object
# Votes            11094 non-null object
# Reviews          11094 non-null object
# Delivery_Time    11094 non-null object
# dtypes: object(9)
# memory usage: 780.1+ KB

# %%
Data_Test.head(8)
# Out:
#   Restaurant                             Location  \
# 0    ID_6321  FTI College, Law College Road, Pune
# 1    ID_2882                 Sector 3, Marathalli
# 2    ID_1595                       Mumbai Central
# 3    ID_5929                      Sector 1, Noida
# 4    ID_6123   Rmz Centennial, I Gate, Whitefield
# 5    ID_5221   Rmz Centennial, I Gate, Whitefield
# 6    ID_3777                       Mumbai Central
# 7     ID_745           Delhi University-GTB Nagar
#
#                                  Cuisines Average_Cost Minimum_Order Rating  \
# 0  Fast Food, Rolls, Burger, Salad, Wraps         ₹200           ₹50    3.5
# 1                     Ice Cream, Desserts         ₹100           ₹50    3.5
# 2         Italian, Street Food, Fast Food         ₹150           ₹50    3.6
# 3          Mughlai, North Indian, Chinese         ₹250           ₹99    3.7
# 4                         Cafe, Beverages         ₹200           ₹99    3.2
# ...

# %%
Data_Test.shape
# Out:
# (11094, 9)

# %%
Data_Test.isnull().sum()
# Out:
# Restaurant       0
# Location         0
# Cuisines         0
# Average_Cost     0
# Minimum_Order    0
# Rating           0
# Votes            0
# Reviews          0
# Delivery_Time    0
# dtype: int64

# %%
Data_Test.describe()
# Out:
#        Restaurant                                    Location      Cuisines  \
# count       11094                                       11094         11094
# unique       7480                                          35          2179
# top       ID_7184  Mico Layout, Stage 2, BTM Layout,Bangalore  North Indian
# freq           22                                         947           850
#
#        Average_Cost Minimum_Order Rating  Votes Reviews Delivery_Time
# count         11094         11094  11094  11094   11094         11094
# unique           26            18     33   1103     761             7
# top            ₹200           ₹50      -      -       -    30 minutes
# freq           3241         10118   1191   2074    2312          7406

# %%
Data_Test
# Out:
#       Restaurant                                          Location  \
# 0        ID_6321               FTI College, Law College Road, Pune
# 1        ID_2882                              Sector 3, Marathalli
# 2        ID_1595                                    Mumbai Central
# 3        ID_5929                                   Sector 1, Noida
# 4        ID_6123                Rmz Centennial, I Gate, Whitefield
# 5        ID_5221                Rmz Centennial, I Gate, Whitefield
# 6        ID_3777                                    Mumbai Central
# 7         ID_745                        Delhi University-GTB Nagar
# 8        ID_2970                        Delhi University-GTB Nagar
# 9        ID_3474                                   Sector 1, Noida
# 10       ID_5159                                    Mumbai Central
# 11       ID_1696                       Yerawada, Pune, Maharashtra
# 12       ID_1156                                   Sector 1, Noida
# ...

# %%
X = Data_Test.iloc[:,:].values

# %%
Y = pd.DataFrame(X)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
clf = LabelEncoder()

# %%
X[:,1] = clf.fit(X[:,1])
Y = pd.DataFrame(X)

# %%
Data_Test.head()
# Out:
#   Restaurant        Location                                Cuisines  \
# 0    ID_6321  LabelEncoder()  Fast Food, Rolls, Burger, Salad, Wraps
# 1    ID_2882  LabelEncoder()                     Ice Cream, Desserts
# 2    ID_1595  LabelEncoder()         Italian, Street Food, Fast Food
# 3    ID_5929  LabelEncoder()          Mughlai, North Indian, Chinese
# 4    ID_6123  LabelEncoder()                         Cafe, Beverages
#
#   Average_Cost Minimum_Order Rating Votes Reviews Delivery_Time
# 0         ₹200           ₹50    3.5    12       4    30 minutes
# 1         ₹100           ₹50    3.5    11       4    30 minutes
# 2         ₹150           ₹50    3.6    99      30    65 minutes
# 3         ₹250           ₹99    3.7   176      95    30 minutes
# 4         ₹200           ₹99    3.2   521     235    65 minutes

# %%
# Out:
#   Restaurant Average_Cost Minimum_Order Rating Votes Reviews Delivery_Time
# 0    ID_6321         ₹200           ₹50    3.5    12       4    30 minutes
# 1    ID_2882         ₹100           ₹50    3.5    11       4    30 minutes
# 2    ID_1595         ₹150           ₹50    3.6    99      30    65 minutes
# 3    ID_5929         ₹250           ₹99    3.7   176      95    30 minutes
# 4    ID_6123         ₹200           ₹99    3.2   521     235    65 minutes

# %%
# Out:
# dtype('O')

# %%
Data_Test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11094 entries, 0 to 11093
# Data columns (total 7 columns):
# Restaurant       11094 non-null object
# Average_Cost     11094 non-null object
# Minimum_Order    11094 non-null object
# Rating           11094 non-null object
# Votes            11094 non-null object
# Reviews          11094 non-null object
# Delivery_Time    11094 non-null object
# dtypes: object(7)
# memory usage: 606.8+ KB

# %%
Data_Test.Average_Cost = [x.strip('$') for x in Data_Test.Average_Cost]

# %%
Data_Test['Average_Cost'].unique()
# Out:
# array(['₹200', '₹100', '₹150', '₹250', '₹650', '₹350', '₹800', '₹50',
#        '₹400', '₹600', '₹300', '₹750', '₹450', '₹550', '₹1,000', '₹500',
#        '₹900', '₹1,200', '₹950', '₹850', '₹700', '₹1,150', 'for',
#        '₹1,100', '₹1,400', '₹2,050'], dtype=object)

# %%
Data_Test[Data_Test['Average_Cost'] == 'for']
# Out:
#      Restaurant Average_Cost Minimum_Order Rating Votes Reviews Delivery_Time
# 6297    ID_6472          for           ₹50    NEW     -       -    30 minutes

# %%
Data_Test['Average_Cost'].replace('for', '200', inplace = True)

# %%
Data_Test['Average_Cost_Cleaned'] = Data_Test['Average_Cost'].apply(lambda x: int(re.sub("[^0-9]", "", x)))

# %%
Data_Test['Average_Cost_Cleaned'].unique()
# Out:
# array([ 200,  100,  150,  250,  650,  350,  800,   50,  400,  600,  300,
#         750,  450,  550, 1000,  500,  900, 1200,  950,  850,  700, 1150,
#        1100, 1400, 2050], dtype=int64)

# %%
Data_Test['Minimum_Order'].unique()
# Out:
# array(['₹50', '₹99', '₹0', '₹200', '₹450', '₹350', '₹79', '₹400', '₹199',
#        '₹500', '₹250', '₹150', '₹90', '₹299', '₹300', '₹240', '₹89',
#        '₹59'], dtype=object)

# %%
Data_Test['Minimum_Order_Cleaned'] = Data_Test['Minimum_Order'].apply(lambda x: int(re.sub("[^0-9]", "", x)))

# %%
Data_Test['Minimum_Order_Cleaned'].unique()
# Out:
# array([ 50,  99,   0, 200, 450, 350,  79, 400, 199, 500, 250, 150,  90,
#        299, 300, 240,  89,  59], dtype=int64)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-a3d6581fcc21> in <module>
# ----> 1 Data_Test['Rating_Cleaned'] = replace_nn_with(Data_Test['Rating'],float, method = 'mean')
#       2
#
# NameError: name 'replace_nn_with' is not defined
